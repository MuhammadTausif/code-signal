# %% [markdown]
# #  This is a simple flask app

# %%
from flask import Flask

def cal_me():
    return "<h1>Hello, World! Good, now changing the word from IP 103.163.239.46</h1>"

app = Flask(__name__)

@app.route('/')
def home():
    return cal_me()

if __name__ == '__main__':
    # app.run(debug=True)
    # app.run(host='192.168.100.5', port=5000)
    app.run(host='103.163.239.46', port=5000)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# The requested address is not valid in its context
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\werkzeug\serving.py:746, in BaseWSGIServer.__init__(self, host, port, app, handler, passthrough_errors, ssl_context, fd)
#     745 try:
# --> 746     self.server_bind()
#     747     self.server_activate()
#
# File C:\Python311\Lib\http\server.py:136, in HTTPServer.server_bind(self)
#     135 """Override server_bind to store the server name."""
# --> 136 socketserver.TCPServer.server_bind(self)
#     137 host, port = self.server_address[:2]
#
# File C:\Python311\Lib\socketserver.py:472, in TCPServer.server_bind(self)
#     471     self.socket.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEPORT, 1)
# --> 472 self.socket.bind(self.server_address)
# ...
